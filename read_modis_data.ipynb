# %%
import datetime
import pandas as pd
import numpy as np

# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import bands
import read_modis_data
import ioexcel
import os
from pathlib import Path
import read_modis_data

# %%
Sites = read_modis_data.read_bioatmosphere_data_from_excel()
# Out:
# NWA

# %%
Sites
#Sites['Date']=Sites['Date'].apply(read_modis_data.convert_modis_to_calendar_dates)
# Out:
#       250m_16_days_EVI  250m_16_days_NDVI  Fpar_500m  Lai_500m  LST_Day_1km  \
# Site
# NWA1         -0.011956           0.044264  -0.093507 -0.631102     2.274236
# NWA1         -0.012565           0.056804  -0.033958 -0.477191     2.274236
# NWA1         -0.010003           0.055159  -0.056961 -0.537117     2.274236
# NWA1          0.004165           0.054963  -0.052721 -0.383563     2.274236
# NWA1          0.008737           0.056961  -0.028514 -0.295472     2.274236
# ...                ...                ...        ...       ...          ...
# NWD1          0.181724           0.168025   0.127294  0.385305    11.959173
# NWD1          0.226389           0.270133   0.039110 -0.144270     2.512466
# NWD1          0.243562           0.264741   0.193873  0.487856     8.852671
# NWD1          0.238199           0.271021   0.193938  0.413933     8.511477
# NWD1          0.238199           0.271021   0.216076  0.524180    10.403720
#
#       LST_Night_1km      Date
# Site
# ...

# %%
_dfFIRE, _modis_data_b4fire = read_modis_data.read_modis_data_from_csv()
# Out:
# NWA
# Sites: (33280, 7) Index(['NWA1', 'NWA10', 'NWA11', 'NWA12', 'NWA13', 'NWA14', 'NWA15', 'NWA16',
#        'NWA17', 'NWA18', 'NWA19', 'NWA2', 'NWA20', 'NWA21', 'NWA22', 'NWA23',
#        'NWA24', 'NWA25', 'NWA26', 'NWA27', 'NWA28', 'NWA29', 'NWA3', 'NWA30',
#        'NWA31', 'NWA32', 'NWA33', 'NWA34', 'NWA35', 'NWA36', 'NWA37', 'NWA38',
#        'NWA39', 'NWA4', 'NWA40', 'NWA41', 'NWA42', 'NWA43', 'NWA44', 'NWA45',
#        'NWA46', 'NWA47', 'NWA48', 'NWA49', 'NWA5', 'NWA50', 'NWA51', 'NWA52',
#        'NWA53', 'NWA54', 'NWA55', 'NWA56', 'NWA57', 'NWA58', 'NWA59', 'NWA6',
#        'NWA60', 'NWA61', 'NWA62', 'NWA63', 'NWA7', 'NWA8', 'NWA9', 'NWD1'],
#       dtype='object', name='Site')
# NW_ClassD
# NW_ClassA
# NR_ClassD
# NR_ClassA
# SW_ClassD
# SW_ClassA
# SA_ClassD
# SA_ClassA
# GB_ClassD
# GB_ClassA
# RM_ClassD
# RM_ClassA
# AK_ClassD
# AK_ClassA
# EA_ClassD
# EA_ClassA

# %%
_modis_data_b4fire.loc[["NWA6"]]
# Out:
#       250m_16_days_EVI  250m_16_days_NDVI  Fpar_500m  Lai_500m  LST_Day_1km  \
# Site
# NWA6         -0.063918          -0.035807  -0.248428 -0.965204    11.212721
# NWA6         -0.056702          -0.033798  -0.170543 -0.807958    11.212721
# NWA6         -0.058414          -0.037156  -0.167699 -0.718162    11.212721
# NWA6         -0.058590          -0.038092  -0.160556 -0.675688    11.212721
# NWA6         -0.043062          -0.035029  -0.150837 -0.644055    11.212721
# ...                ...                ...        ...       ...          ...
# NWA6         -0.043335           0.006556  -0.136487 -0.737933     6.546854
# NWA6         -0.052541          -0.007174  -0.088783 -0.821096     4.542473
# NWA6         -0.051102          -0.006063  -0.099625 -0.842780     0.993796
# NWA6         -0.047931          -0.003420  -0.104574 -0.856555    -4.284055
# NWA6         -0.052555           0.009949  -0.102992 -0.856810     1.240242
#
#       LST_Night_1km       Date
# Site
# ...

# %%
np.unique(_modis_data_b4fire.index.values)
# Out:
# array(['NWA10', 'NWA13', 'NWA17', 'NWA2', 'NWA20', 'NWA21', 'NWA22',
#        'NWA26', 'NWA34', 'NWA36', 'NWA37', 'NWA38', 'NWA39', 'NWA40',
#        'NWA42', 'NWA44', 'NWA45', 'NWA47', 'NWA49', 'NWA5', 'NWA50',
#        'NWA51', 'NWA52', 'NWA56', 'NWA57', 'NWA6', 'NWA60', 'NWA62',
#        'NWA63', 'NWD1'], dtype=object)

# %%
_modis_data_b4fire.loc[["NWA6"]]
# Out:
#       250m_16_days_EVI  250m_16_days_NDVI  Fpar_500m  Lai_500m  LST_Day_1km  \
# Site
# NWA6         -0.063918          -0.035807  -0.248428 -0.965204    11.212721
# NWA6         -0.056702          -0.033798  -0.170543 -0.807958    11.212721
# NWA6         -0.058414          -0.037156  -0.167699 -0.718162    11.212721
# NWA6         -0.058590          -0.038092  -0.160556 -0.675688    11.212721
# NWA6         -0.043062          -0.035029  -0.150837 -0.644055    11.212721
# ...                ...                ...        ...       ...          ...
# NWA6         -0.043335           0.006556  -0.136487 -0.737933     6.546854
# NWA6         -0.052541          -0.007174  -0.088783 -0.821096     4.542473
# NWA6         -0.051102          -0.006063  -0.099625 -0.842780     0.993796
# NWA6         -0.047931          -0.003420  -0.104574 -0.856555    -4.284055
# NWA6         -0.052555           0.009949  -0.102992 -0.856810     1.240242
#
#       LST_Night_1km       Date
# Site
# ...

# %%
_modis_data_b4fire
# Out:
#        250m_16_days_EVI  250m_16_days_NDVI  Fpar_500m  Lai_500m  LST_Day_1km  \
# Site
# NWA10         -0.031703          -0.018497  -0.238512 -0.988570    -3.401576
# NWA10         -0.042684          -0.023735  -0.097731 -0.648004    -3.401576
# NWA10         -0.038707          -0.023049  -0.092353 -0.646252    -3.401576
# NWA10         -0.020692          -0.006532  -0.121262 -0.649217    -3.401576
# NWA10         -0.027679          -0.011903  -0.216100 -0.800206    -3.401576
# ...                 ...                ...        ...       ...          ...
# NWD1           0.242907           0.266070   0.176245  0.469016    10.822225
# NWD1           0.232761           0.248586   0.168858  0.241260    10.358024
# NWD1           0.196303           0.225137   0.148996  0.138643    11.342308
# NWD1           0.178209           0.186400   0.075222 -0.146205    12.123907
# NWD1           0.150429           0.162817   0.001117 -0.407775    13.656430
#
#        LST_Night_1km       Date
# ...

# %%
_year = pd.DataFrame()
for i in np.unique(_modis_data_b4fire.index.values):
    #print(i)
    _site = _modis_data_b4fire.loc[[i]]
    _site = _site.sort_values(['Date'], ascending=True)
    _site_collapsed = read_modis_data.collapse_modis_data(_site)
    _year = pd.concat([_year, _site_collapsed])
_year.set_index('Site', inplace=True)
# Out:
# index: NWA10
# _year.columns: Index(['250m_16_days_EVI', '250m_16_days_NDVI', 'Fpar_500m', 'Lai_500m',
#        'LST_Day_1km', 'LST_Night_1km'],
#       dtype='object')
# _year.columns: Index(['250m_16_days_EVI', '250m_16_days_NDVI', 'Fpar_500m', 'Lai_500m',
#        'LST_Day_1km', 'LST_Night_1km'],
#       dtype='object')
# index: NWA13
# _year.columns: Index(['250m_16_days_EVI', '250m_16_days_NDVI', 'Fpar_500m', 'Lai_500m',
#        'LST_Day_1km', 'LST_Night_1km'],
#       dtype='object')
# _year.columns: Index(['250m_16_days_EVI', '250m_16_days_NDVI', 'Fpar_500m', 'Lai_500m',
#        'LST_Day_1km', 'LST_Night_1km'],
#       dtype='object')
# index: NWA17
# _year.columns: Index(['250m_16_days_EVI', '250m_16_days_NDVI', 'Fpar_500m', 'Lai_500m',
#        'LST_Day_1km', 'LST_Night_1km'],
#       dtype='object')
# _year.columns: Index(['250m_16_days_EVI', '250m_16_days_NDVI', 'Fpar_500m', 'Lai_500m',
#        'LST_Day_1km', 'LST_Night_1km'],
#       dtype='object')
# index: NWA2
# ...

# %%
_year = pd.merge(_year, _dfFIRE, left_index=True, right_index=True)

# %%
_year
_year.to_csv("bioatmosphere_regression_data.csv")

# %%
_year
# Out:
#        250m_16_days_EVI-0  50m_16_days_NDVI-0  Fpar_500m-0  Lai_500m-0  \
# Site
# NWA10            0.045388            0.080381     0.119108    0.760959
# NWA13           -0.104454           -0.275847    -0.271303   -1.069847
# NWA17           -0.083291           -0.221945    -0.054163   -0.277813
# NWA2             0.061777            0.130451     0.028141    0.009648
# NWA20            0.023972            0.056965     0.069956    0.328455
# NWA21            0.029234            0.056260     0.060488    0.650243
# NWA22            0.048704            0.009016    -0.026717   -0.352035
# NWA26           -0.118782           -0.276215    -0.146863   -0.620357
# NWA34           -0.036967           -0.110882    -0.113333   -0.719890
# NWA36            0.032279            0.093158     0.093405    0.444660
# NWA37           -0.061813           -0.179044    -0.133229   -0.759825
# NWA38           -0.012009           -0.058789    -0.016790   -0.164243
# ...

# %%
_year

# %%
_modis_data_b4fire

# %%
import seaborn as sns
# %matplotlib inline
for i in np.unique(_year_1.index.values):
    print(i)
    _df = _year_1.loc[[i]]

    #_dfTail= _df.tail(48)
    #dfQuarter = _dfTail.groupby(np.arange(len(_dfTail))//12).mean()
    df_norm_col=(_df-_df.mean())/_df.std()
    sns.heatmap(df_norm_col, cmap='viridis')
    print(df_norm_col)
    plt.show()

# %%
 import pandas as pd
colnames=['Date', 'Site', '250m_16_days_EVI', '250m_16_days_NDVI', 'Fpar_500m', 
      'Lai_500m', 'ET_500m','LE_500m','PET_500m', 'PLE_500m', 'LST_Day_1km', 'LST_Night_1km', 'scaled_250m_16_days_EVI'] 

Sites = pd.read_csv("bioatmosphere_data_1_180.csv", names=colnames, index_col=1, header=0)
#Drop the column which are not used
columns_to_drop = ['ET_500m', 'LE_500m', 'PET_500m', 'PLE_500m', 'scaled_250m_16_days_EVI'] #, 'Unknown']
Sites.drop(columns_to_drop, axis=1, inplace=True)
Sites = Sites[Sites['250m_16_days_EVI'].notna()]

## Load the fires into dataframe. We need the date when the fire occured.
#_df = read_fires_from_excel()

# %%
_dfSites = Sites.dropna()

# %%
_dfSites.loc[1]['250m_16_days_NDVI'].plot()

# %%
_dfSites['Date']=_dfSites['Date'].apply(read_modis_data.convert_modis_to_calendar_dates)

# %%
_df1 = _dfSites[['Date', '250m_16_days_NDVI', '250m_16_days_EVI','Fpar_500m']]

# %%
#_df1.set_index('Date', inplace=True)

# %%
_df1

# %%
_df1

# %%
_df2 = _df1.loc[(_df1.index == 1)]

# %%
_df2.corr()

# %%
#greater than the start date and smaller than the end date
mask = (_df2['Date'] < "2010-01-01")
_df3 = _df2.loc[mask]

# %%
_df3.set_index('Date', inplace=True)

# %%
_df3.plot()

# %%
_dff = read_modis_data.read_fires_from_excel()

# %%
_dff

# %%
import sqlite3  
import ioexcel
from pathlib import Path
conn = sqlite3.connect('data/FPA_FOD_20170508.sqlite')
#in lieu of dataframe manipulation in the next code block:
df = pd.read_sql_query("""SELECT *
                       FROM Fires""", conn)

# %%
[df.columns]

# %%
df[['FIRE_YEAR']]

# %%
df.plot.scatter(x='FIRE_SIZE', y='LONGITUDE')

# %%
df.plot.scatter(x='FIRE_SIZE', y='LATITUDE')

# %%
ax = df.plot.scatter(x='FIRE_YEAR', y='FIRE_SIZE') 
#df.set_index('FIRE_YEAR', inplace=True)
#df.trendline.sort_index(ascending=False).plot(ax=ax)
#plt.gca().invert_xaxis()

# %%
 df.plot.scatter(x='FIRE_YEAR', y='LONGITUDE')

# %%
ax = df.plot.scatter(x='FIRE_YEAR', y='FIRE_SIZE')

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.hist(df['FIRE_YEAR'], rwidth=0.9, bins=24);
ax.set_xlabel('Year')
ax.set_ylabel('Amount of Fire Incidents')
plt.title('Incidents by Years')

# %%
df.loc[df['FIRE_SIZE_CLASS']=='C']

# %%
df.query("LONGITUDE=='-112.802778'").sort_values(by='FIRE_SIZE')

# %%
df

# %%
_df_top_fires = df.query("FIRE_SIZE > 50000 & FIRE_YEAR> 2004").sort_values(by='FIRE_SIZE')

# %%
_df_top_fires[['FIRE_SIZE_CLASS']] #.columns

# %%
_dfCA = df.query("STATE=='CA'").sort_values(by='FIRE_SIZE')

# %%
_dfCA = _dfCA[["FIRE_YEAR", "DISCOVERY_DOY", "DISCOVERY_DATE", "LATITUDE", "LONGITUDE", "FIRE_SIZE"]]

# %%
_dfCA

# %%
_dfCA['MONTH'] = pd.DatetimeIndex(_dfCA['DISCOVERY_DATE']).month

# %%
_dfCA

# %%
_dfCA['MONTH'].value_counts()

# %%
pd.DatetimeIndex(_dfCA['DISCOVERY_DATE']).month

# %%
read_modis_data.read_fires_from_excel().sort_values('Site')

# %%
read_modis_data.read_modis_data_from_csv()

# %%
Sites = read_modis_data.read_bioatmosphere_data_from_excel()
    #Drop the column which are not used

# %%
Sites.index.unique()

# %%
n1 = float("2.0")
n2 = None
n3 = float("NaN")
n4 = float("NAN")
print(n1, n2, n3, n4)

# %%
(n1+n2)/2

# %%
_cols = ["250m_16_days_EVI", "250m_16_days_NDVI", "Fpar_500m", "Lai_500m", "LST_Day_1km", "LST_Night_1km"]
Sites = Sites.fillna(method='ffill')
_sites_shifted = (Sites[_cols] + Sites[_cols].shift(-1))/2
_sites_shifted['Date'] = Sites['Date']
__sites_shifted = _sites_shifted.loc[_sites_shifted.groupby('Site').cumcount().mod(2).eq(0)] 
#_sites_shifted = _sites_shifted.iloc[::2]  ##Remove even rows since the odd row contains the average of the two rows.
_sites_shifted[_cols] = _sites_shifted[_cols]-_sites_shifted[_cols].mean(axis = 0, skipna = True)

# %%
for i in range (3,0,-1):
    print(i)

# %%
for i in range(3):
    print(i)
